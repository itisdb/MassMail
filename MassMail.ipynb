# %%
# !git clone https://github.com/itisdb/MassMail.git

# %%
#!python '/content/MassMail/massmail.py' -e emailid -s excel -sl subject -m message
#Enter the email id to send in place of emailid, excel file link in place of excel, Subject in place of of Subject and HTML file link in place of html

# !python '/content/MassMail/massmail.py' -e emailid -s excel -sl "subject" -m message

# %%
# !git clone https://github.com/itisdb/MassMail.git

# %%
excel=input("Enter the Excel file link : ")
message=input("Enter the link for the HTML email : ")
subject=input("Enter the Subject for the Email : ")
emailid=input("Enter the EmailID you want to send from : ")

# %%
# !python '/content/MassMail/massmail.py' -e emailid -s excel -sl subject -m message
